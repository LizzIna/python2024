# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,4,8,16])
plt.title("Mi amorcito")

plt.xlabel("Cesarito")
plt.ylabel("Vale hedionda")
plt.grid()

# %%
t = np.arange(0,10,1)
f1 = 4*t
f2 = t**2
f3= [1,6,8,10,30,50,60,75,80,110]
plt.grid(True)
plt.plot(t,f1,t,f2,t,f3)
plt.legend(("Ejemplo 1", "Ejemplo 2", "Ejemplo 3"))
